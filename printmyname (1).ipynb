# %% [markdown]
# # **my frist program**

# %%
print("i am swayam")
# Out:
# i am swayam

# %% [markdown]
# **vraiable declaration in python**

# %%
a=5
b=6
sum=a+b
print(sum)
# Out:
# 11

# %% [markdown]
# subtraction

# %%
a=10
b=5
sub=a-b
print(sub)
# Out:
# 5

# %%
a=20
b=5
c=6
sub=a-b-c
print(sub)
# Out:
# 9

# %% [markdown]
# multiplication

# %%
a=10
b=5
mul=a*b
print(mul)
# Out:
# 50

# %% [markdown]
# division

# %%
a=3
b=2
div=a//b
rem=a%b
print(div)
print(rem)
# Out:
# 1
# 1

# %% [markdown]
# square of a number

# %%
a=10
sqr=a*a
print(sqr)
# Out:
# 100

# %% [markdown]
# **square root**

# %%
import math
a=8
math.sqrt(a)
# Out:
# 2.8284271247461903

# %% [markdown]
# another

# %%
a=3
b=5
c=2
num=a+b/c
print(num)
# Out:
# 5.5

# %%
name = 'swayam'
print(type(name))
# Out:
# <class 'str'>

# %%
num1= 56
num2=69.54
num3=5j
num4=-69
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# # **sequence data type**
# **lists**
# **tuples**
# **range**

# %%
 lis= ['swa','123','30.45']
 type(lis)
# Out:
# list

# %%
print(lis)
# Out:
# ['swa', '123', '30.45']

# %%
lis2=['apple','200','inaia']
print(len(lis))
print(len(lis2))
lis3= lis+ lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 3
# ['swa', '123', '30.45', 'apple', '200', 'inaia']
# 6

# %%
 lis2.append("belgavi")

# %%
lis2
# Out:
# ['apple', '200', 'inaia', 'belgavi']

# %%
lis=['ss','se','rr','tt']
lis[0]
# Out:
# 'ss'

# %%
lis[3]
# Out:
# 'tt'

# %%
lis.sort()

# %%
lis
# Out:
# ['rr', 'se', 'ss', 'tt']

# %% [markdown]
# tuples --> storing multiple items in a single variable
# 1.ordered
# 2.unchangeable
# 3.allow duplicates

# %%
tuple1=("belgavi","hubli","b")
print(type(tuple1))
tuple2=("hubli",)
print(type(tuple2))
tuple3=("gg","123",1,2,3,4,5,True)
print(type(tuple3))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
tuple4=tuple((1,2,3,4,5))
print(type(tuple4))
# Out:
# <class 'tuple'>

# %% [markdown]
# 1.how do we access elements in tuple?
# 2.join tuples
# 3.multlipe tuples
# 4.indexing
# 5.counting

# %%
tuple1=("belgavi","hubli","belgavi")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
tuple6= tuple1 + tuple1
print(tuple6)
tuple7= tuple6 * 2
print(tuple7)
y=tuple7.index('belgavi')
print(y)
x=tuple7.count('belgavi')
print(x)
# Out:
# belgavi
# hubli
# belgavi
# belgavi
# ('belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi')
# ('belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi')
# 0
# 8

# %% [markdown]
# adding element to a tuple

# %%
x=("belgavi","gokak","belgavi")
print(type(tuple))
# Out:
# <class 'type'>

# %%
y=list(x)
y[2]="hubli"
x= tuple(y)
print(x)
# Out:
# ('belgavi', 'gokak', 'hubli')

# %% [markdown]
# # ***sets***
# # 1. unordered
# # 2.unchangeable
# # 3. duplicates r not allowed

# %%
set1={"red","black","blue","red"}
print(set1)
set1.add('orange')
print(set1)
set2={"ball","bat","cat"}
set1.update(set2)
print(set1)
# Out:
# {'blue', 'black', 'red'}
# {'blue', 'black', 'orange', 'red'}
# {'ball', 'blue', 'black', 'cat', 'bat', 'orange', 'red'}

# %% [markdown]
# ## ***dictionaries***

# %%
Dict1= {"name":"swayam",
       "age":"21",
       "gender":"male"}
print(Dict1)
# Out:
# {'name': 'swayam', 'age': '21', 'gender': 'male'}

# %%
print(type(Dict1))
# Out:
# <class 'dict'>

# %%
dict2= dict(fruit="mango",dessert="ice")
print(dict2)
print(type(dict2))
# Out:
# {'fruit': 'mango', 'dessert': 'ice'}
# <class 'dict'>

# %% [markdown]
# # **conditional statements**

# %%
a=input("enter the value of a")
b=input("enter the value of b")
print(a)
print(b)
# Out:
# enter the value of a1
# enter the value of b1
# 1
# 1

# %%
if a>b:
  print("the value of a is grater than b")
if  a==b:
  print("both a and b are same")
else:
    print(a<b)
# Out:
# both a and b are same

# %% [markdown]
# # ***elif***

# %%
ball1_colour="green"
ball2_colour="blue"
ball3_colour="red"
ball4_colour="white"

pick_ball=input("please pick a ball")

if pick_ball == ball1_colour:
  print("green ball is picked")

elif pick_ball == ball2_colour:
  print("blue ball is picked")

elif pick_ball == ball3_colour:
  print("red ball is picked")

else:
  print("white ball is picked")
# Out:
# please pick a ball2
# white ball is picked

# %% [markdown]
# arithmetic

# %%
x=12
y=10

sum=x+y
diff=x-y
mul=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y
print(sum)
print(diff)
print(mul)
print(div)
print(fdiv)
print(mod)
print(power)
# Out:
# 22
# 2
# 120
# 1.2
# 1
# 2
# 61917364224

# %% [markdown]
# **logical operator**

# %%
AND
OR
NOT

# %% [markdown]
# COMPARISON operators

# %%
>,<
==,>=
<=<!=

# %%
age=int(input("enter the age"))
print(age>18 and age<60)
print(age>18 or age<21)
# Out:
# enter the age19
# True
# True

# %% [markdown]
# # ***Assignment-2***

# %% [markdown]
# 1.how to access elements in tuple even join tuple and multiple tuples and do indexing and counting.

# %%
tuple1=("belgavi","hubli","belgavi")
print(tuple1[0])
print(tuple1[1])
print(tuple1[2])
print(tuple1[-1])
tuple6= tuple1 + tuple1
print(tuple6)
tuple7= tuple6 * 2
print(tuple7)
y=tuple7.index('belgavi')
print(y)
x=tuple7.count('belgavi')
print(x)
# Out:
# belgavi
# hubli
# belgavi
# belgavi
# ('belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi')
# ('belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi', 'belgavi', 'hubli', 'belgavi')
# 0
# 8

# %% [markdown]
# 2.Create a set and show the unordered output.And add another set to it.

# %%
set1={"milk","water","sky","ground"}
print(set1)
set1.add('earth')
print(set1)
# Out:
# {'milk', 'sky', 'ground', 'water'}
# {'earth', 'sky', 'water', 'ground', 'milk'}

# %% [markdown]
# 3.Using dictionaries print the name of a city,pincode and area.

# %%
Dict1= {"name of a city":"Belgavi",
       "Area":"Hindlga",
       "Pincode":"591108"}
print(Dict1)
# Out:
# {'name of a city': 'Belgavi', 'Area': 'Hindlga', 'Pincode': '591108'}

# %% [markdown]
# 4.Using the elif show the colour of the cloth, when picked randomly.

# %%
cloth1_colour="green"
cloth2_colour="blue"
cloth3_colour="red"
cloth4_colour="white"

pick_cloth=input("please pick a cloth")

if pick_cloth == cloth1_colour:
  print("green cloth is picked")

elif pick_cloth == cloth2_colour:
  print("blue cloth is picked")

elif pick_cloth == cloth3_colour:
  print("red cloth is picked")

else:
  print("white cloth is picked")
# Out:
# please pick a cloth2
# white cloth is picked

# %% [markdown]
# 5.show the elements in list and add 2 lists.

# %%
lis= ['swa','123','30.45']
print(lis)
lis2=['apple','200','inaia']
print(len(lis))
print(len(lis2))
lis3= lis+ lis2
print(lis3)
print(len(lis3))
# Out:
# ['swa', '123', '30.45']
# 3
# 3
# ['swa', '123', '30.45', 'apple', '200', 'inaia']
# 6
